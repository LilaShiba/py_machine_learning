# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
front = pd.read_csv('front.csv', encoding='utf-8')

# %%
front.head(5)
# Out:
#   Your name         name                stage   Rec  \
# 0   Bentley      Stephan  Stage 3 - Prototype  Hold
# 1     Lloyd  Spark tutor       Stage 1 - Idea  Hold
# 2   Bentley  Spark tutor       Stage 1 - Idea  Pass
# 3    Rachel  Spark Tutor       Stage 1 - Idea  Hold
# 4      Zach  Spark tutor       Stage 1 - Idea  Pass
#
#                                                level  pitch_rep  clear_usr  \
# 0  Level 1 - Solution Defined but not yet impleme...          2          2
# 1  Level 0 - Problem defined. Solution not yet de...          3          2
# 2  Level 1 - Solution Defined but not yet impleme...          3          5
# 3  Level 1 - Solution Defined but not yet impleme...          2          3
# 4  Level 1 - Solution Defined but not yet impleme...          3          2
#
#    problem_pain  sol_prob  effective  stats
# 0             4       2.0          2      1
# 1             2       2.0          2      1
# 2             3       3.0          3      1
# ...

# %%
sns.jointplot(x='pitch_rep', y='effective', data=front, kind='hex')

# %%
pc = front.corr()

# %%
sns.heatmap(pc,annot=True,cmap='coolwarm')

# %%
sns.countplot(x='pitch_rep',data=front)

# %%
sns.countplot(x='sol_prob',data=front)

# %%
sns.lmplot(x='sol_prob', y='pitch_rep', data=front)

# %%
sns.lmplot(x='problem_pain', y='pitch_rep', data=front)

# %%
sns.lmplot(x='problem_pain', y='effective', data=front)

# %%
sns.lmplot(x='problem_pain', y='sol_prob', data=front)

# %%
sns.jointplot(x='sol_prob', y='effective', data=front, kind='hex')
