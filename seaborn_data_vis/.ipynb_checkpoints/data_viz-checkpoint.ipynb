# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt

# %%
# Read dataset
poke = pd.read_csv('pokemon.csv')

# %%
poke.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
sns.lmplot(x='Attack', y='Defense', data=poke)

# %%
sns.set_style('whitegrid')
sns.jointplot(x='Attack', y='HP', data=poke, kind='hex')

# %%
sns.rugplot(poke['Attack'])

# %%
sns.jointplot(x='Speed', y='Defense', data=poke, kind='hex')

# %%
sns.jointplot(x='Speed', y='Attack', data=poke, kind='hex')

# %%
sns.kdeplot(poke['Attack'])

# %%
np.mean(poke['Attack'])
# Out:
# 79.00125

# %%
np.mean(poke['Defense'])
# Out:
# 73.8425

# %%
np.std(poke['Defense'])
# Out:
# 31.164004777146342

# %%
np.std(poke['Attack'])
# Out:
# 32.43707367253557

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                    '#F8D030',  # Electric
                    '#E0C068',  # Ground
                    '#EE99AC',  # Fairy
                    '#C03028',  # Fighting
                    '#F85888',  # Psychic
                    '#B8A038',  # Rock
                    '#705898',  # Ghost
                    '#98D8D8',  # Ice
                    '#7038F8',  # Dragon
                   ]

# %%
plt.figure(figsize=(20,10), dpi=100)
sns.violinplot(x='Type 1', y='Attack', data=poke, palette=pkmn_type_colors)
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0, 17.5)

# %%
plt.figure(figsize=(20,10), dpi=100)
my_poke = sns.swarmplot(x='Type 1', y='Attack', data=poke, palette=pkmn_type_colors)

# %%
plt.figure(figsize=(20,10), dpi=100)
my_poke = sns.swarmplot(x='Type 1', y='Defense', data=poke, palette=pkmn_type_colors)

# %%
plt.figure(figsize=(20,10), dpi=100)

my_poke = sns.swarmplot(x='Type 1', y='Sp. Atk', data=poke, palette=pkmn_type_colors)

# %%
poke.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
strongpoke = poke[(poke['Attack'] > 150) & (poke['Defense'] > 109)]

# %%
poke.groupby('Type 1').mean()['Attack']
# Out:
# Type 1
# Bug          70.971014
# Dark         88.387097
# Dragon      112.125000
# Electric     69.090909
# Fairy        61.529412
# Fighting     96.777778
# Fire         84.769231
# Flying       78.750000
# Ghost        73.781250
# Grass        73.214286
# Ground       95.750000
# Ice          72.750000
# Normal       73.469388
# Poison       74.678571
# Psychic      71.456140
# Rock         92.863636
# Steel        92.703704
# Water        74.151786
# Name: Attack, dtype: float64

# %%
poke.groupby('Type 1').mean()['Defense']
# Out:
# Type 1
# Bug          70.724638
# Dark         70.225806
# Dragon       86.375000
# Electric     66.295455
# Fairy        65.705882
# Fighting     65.925926
# Fire         67.769231
# Flying       66.250000
# Ghost        81.187500
# Grass        70.800000
# Ground       84.843750
# Ice          71.416667
# Normal       59.846939
# Poison       68.821429
# Psychic      67.684211
# Rock        100.795455
# Steel       126.370370
# Water        72.946429
# Name: Defense, dtype: float64

# %%
poke.groupby('Type 1').std()['Attack']
# Out:
# Type 1
# Bug         37.040904
# Dark        25.774247
# Dragon      33.742622
# Electric    23.764169
# Fairy       29.751298
# Fighting    28.290163
# Fire        28.769275
# Flying      37.500000
# Ghost       29.629687
# Grass       25.380520
# Ground      33.059087
# Ice         27.289511
# Normal      30.295862
# Poison      19.630010
# Psychic     42.309265
# Rock        35.325458
# Steel       30.388276
# Water       28.377192
# Name: Attack, dtype: float64

# %%
poke.groupby('Type 1').std()['Defense']
# Out:
# Type 1
# Bug         33.617609
# Dark        25.121982
# Dragon      24.102938
# Electric    24.757033
# Fairy       18.979478
# Fighting    18.578163
# Fire        23.658200
# Flying      21.360009
# Ghost       32.551138
# Grass       24.485192
# Ground      33.786912
# Ice         34.387708
# Normal      23.771833
# Poison      21.066128
# Psychic     28.359401
# Rock        36.447209
# Steel       44.806548
# Water       27.773809
# Name: Defense, dtype: float64

# %%
poke[['Attack', 'Defense']].corr()
# Out:
#            Attack   Defense
# Attack   1.000000  0.438687
# Defense  0.438687  1.000000

# %%
poke[['Attack', 'Speed']].corr()
# Out:
#          Attack    Speed
# Attack  1.00000  0.38124
# Speed   0.38124  1.00000

# %%
poke[['Attack', 'Sp. Atk']].corr()
# Out:
#            Attack   Sp. Atk
# Attack   1.000000  0.396362
# Sp. Atk  0.396362  1.000000

# %%
type_d = poke.groupby('Type 1')['Defense']

# %%
type_d

# %%
poke[['Attack', 'HP']].corr()
# Out:
#           Attack        HP
# Attack  1.000000  0.422386
# HP      0.422386  1.000000

# %%
poke[['Defense', 'HP']].corr()
# Out:
#           Defense        HP
# Defense  1.000000  0.239622
# HP       0.239622  1.000000

# %%
poke[['Speed', 'Sp. Atk']].corr()
# Out:
#             Speed   Sp. Atk
# Speed    1.000000  0.473018
# Sp. Atk  0.473018  1.000000

# %%
poke.head(4)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
plt.figure(figsize=(20,10), dpi=100)
sns.barplot(x='Type 1', y='HP', data=poke, estimator=np.std)

# %%
plt.figure(figsize=(20,10), dpi=100)
sns.countplot(x='Type 1',data=poke)

# %%
plt.figure(figsize=(20,10), dpi=100)
sns.boxplot(x='Type 1', y='HP', data=poke)

# %%
pc = poke.corr()

# %%
sns.heatmap(pc,annot=True,cmap='coolwarm')

# %%
pp = poke.pivot_table(columns='Type 1', values='Attack')

# %%
sns.heatmap(pp, cmap='magma', linecolor='white', linewidths=3)

# %%
sns.heatmap(pc,cmap='coolwarm')

# %%
poke.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
poke_shift = poke.pivot_table(columns='Type 1', values='Defense')

# %%
sns.heatmap(poke_shift, cmap='magma', linecolor='white', linewidths=3)
